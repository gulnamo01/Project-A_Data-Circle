# %% [markdown]
# # Sprint 2

# %% [markdown]
# ## Task 2.1: Feature Engineering

# %% [markdown]
# #### Ticket 2.1.1: Create new features based on domain knowledge and EDA insights

# %% [markdown]
# ##### 1- Develop features for health behavior patterns and vaccine attitudes

# %% [markdown]
# ##### 2- Generate demographic and geographic risk indicators

# %% [markdown]
# #### Ticket 2.1.2: Transform existing features to improve model performance

# %% [markdown]
# ##### 1- Apply transformations for skewed distributions

# %% [markdown]
# ##### 2- Create normalized versions of count variables

# %% [markdown]
# #### Ticket 2.1.3: Implement feature encoding techniques for categorical variables

# %% [markdown]
# ##### 1- Compare performance of different encoding methods

# %% [markdown]
# ##### 2- Handle high-cardinality categorical variables

# %% [markdown]
# #### Ticket 2.1.4: Create feature interaction terms if appropriate

# %% [markdown]
# ##### 1- Generate interaction terms between demographic and behavioral features

# %% [markdown]
# ##### 2- Test interaction terms for statistical significance

# %% [markdown]
# #### Ticket 2.1.5: Document all feature engineering steps

# %% [markdown]
# ##### 1- Create documentation of all engineered features and transformations

# %% [markdown]
# ##### 2- Explain the rationale behind each new feature

# %% [markdown]
# ## Task 2.2: Baseline Model Creation

# %% [markdown]
# #### Ticket 2.2.1: Split data into training and validation sets

# %% [markdown]
# ##### 1- Implement stratified splitting to maintain class distribution

# %% [markdown]
# ##### 2- Verify splits have similar distributions of key variables

# %% [markdown]
# #### Ticket 2.2.2: Implement cross-validation strategy

# %% [markdown]
# ##### 1- Design a k-fold cross-validation approach

# %% [markdown]
# ##### 2- Create reusable validation function for model evaluation

# %% [markdown]
# #### Ticket 2.2.3: Train baseline models for H1N1 vaccine prediction

# %% [markdown]
# ##### 1- Implement multiple classifier types (logistic regression, decision tree, etc.)

# %% [markdown]
# ##### 2- Use default hyperparameters for initial performance assessment

# %% [markdown]
# #### Ticket 2.2.4: Train baseline models for seasonal vaccine prediction

# %% [markdown]
# ##### 1- Adapt the H1N1 modeling pipeline for seasonal flu prediction

# %% [markdown]
# ##### 2- Compare performance differences between the two targets

# %% [markdown]
# #### Ticket 2.2.5: Evaluate baseline performance using ROC AUC

# %% [markdown]
# ##### 1- Calculate ROC AUC scores and generate ROC curves

# %% [markdown]
# ##### 2- Create a benchmark table comparing all baseline models

# %% [markdown]
# ## Task 2.3: Model Selection and Comparison

# %% [markdown]
# #### Ticket 2.3.1: Implement multiple classification algorithms

# %% [markdown]
# ##### 1- Test both linear models and tree-based methods

# %% [markdown]
# ##### 2- Create a standard interface for all models

# %% [markdown]
# #### Ticket 2.3.2: Compare model performances across algorithms

# %% [markdown]
# ##### 1- Create comparison table with multiple metrics

# %% [markdown]
# ##### 2- Analyze training time and computational requirements

# %% [markdown]
# #### Ticket 2.3.3: Analyze differences in model performance between H1N1 and seasonal flu targets

# %% [markdown]
# ##### 1- Compare performance patterns across different demographic groups

# %% [markdown]
# ##### 2- Identify which features are more predictive for each target

# %% [markdown]
# #### Ticket 2.3.4: Document strengths and weaknesses of each approach

# %% [markdown]
# ##### 1- Analyze interpretability vs. performance tradeoffs

# %% [markdown]
# ##### 2- Create a decision matrix for model selection

# %% [markdown]
# ## Task 2.4: Hyperparameter Tuning

# %% [markdown]
# #### Ticket 2.4.1: Define hyperparameter search spaces for top-performing models

# %% [markdown]
# ##### 1- Identify key hyperparameters for each selected model

# %% [markdown]
# ##### 2- Create logical parameter grids for searching

# %% [markdown]
# #### Ticket 2.4.2: Implement grid or random search for hyperparameter optimization

# %% [markdown]
# ##### 1- Configure search with appropriate scoring metrics (ROC AUC)

# %% [markdown]
# ##### 2- Implement cross-validation within the search process

# %% [markdown]
# #### Ticket 2.4.3: Evaluate tuned models using cross-validation

# %% [markdown]
# ##### 1- Compare tuned models to baseline performance

# %% [markdown]
# ##### 2- Assess potential overfitting from excessive tuning

# %% [markdown]
# #### Ticket 2.4.4: Document performance improvements from tuning

# %% [markdown]
# ##### 1- Create before/after comparison tables

# %% [markdown]
# ##### 2- Document the most influential hyperparameters

# %% [markdown]
# ## Task 2.5: Model Evaluation and Documentation

# %% [markdown]
# #### Ticket 2.5.1: Perform final evaluation on validation set

# %% [markdown]
# ##### 1- Calculate comprehensive performance metrics

# %% [markdown]
# ##### 2- Identify subgroups where model performance varies

# %% [markdown]
# #### Ticket 2.5.2: Analyze feature importance from the models

# %% [markdown]
# ##### 1- Extract and visualize feature importance rankings

# %% [markdown]
# ##### 2- Compare importance between H1N1 and seasonal flu models

# %% [markdown]
# #### Ticket 2.5.3: Create confusion matrices and ROC curves

# %% [markdown]
# ##### 1- Generate visualization of model performance metrics

# %% [markdown]
# ##### 2- Analyze model errors for further improvement

# %% [markdown]
# #### Ticket 2.5.4: Document model pipeline and performance metrics

# %% [markdown]
# ##### 1- Create comprehensive modeling report

# %% [markdown]
# ##### 2- Document final model selection rationale

# %% [markdown]
# #### Ticket 2.5.5: Prepare presentation for Sprint 2 review

# %% [markdown]
# ##### 1- Create slides highlighting modeling process and results

# %% [markdown]
# ##### 2- Outline plans for the final sprint
